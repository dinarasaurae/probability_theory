# %% [markdown]
# # Вариант 9

# %% [markdown]
# # Задание 1

# %% [markdown]
# ## № 2. Условие
# Игральный кубик бросается 5 раз. Какова вероятность того, что в результате будут выпадать
# только 2 числа, причем одно появится дважды, другое – трижды?

# %% [markdown]
# ## Решение
# 1 способ
#
# $ P = \frac{6 \cdot 5 C^3_5}{6^5} \approx 0.038 $
#
# 2 способ
#
# $ P = 2 С^2_5 \cdot (\frac{1}{6})^3 \cdot (\frac{1}{6})^2 \cdot C^2_6 \approx 0.038 $

# %%
from math import factorial

combinations = factorial(5)/(factorial(3)*factorial(5-3))
result = (6*5*combinations)/(6**5)
print(result)
# Out:
# 0.038580246913580245

# %%
from math import factorial

combinations1 = factorial(5)/(factorial(3)*factorial(5-3))
combinations2 = factorial(6)/(factorial(2)*factorial(6-2))
result = 2 * combinations1 * ((1/6)**3) * ((1/6)**2) * combinations2
print(result)
# Out:
# 0.03858024691358023

# %% [markdown]
# ## № 3. Условие

# %% [markdown]
# В коробке лежат 70 фруктов, 10 из которых испорчены. Наугад берутся 5 фруктов. С какой
# вероятность среди выбранных фруктов есть и испорченные, и хорошие?

# %% [markdown]
# ## Решение
# Для решения данной задачи можно пойти от обратного: исключить варианты когда есть только испорченные и только хорошие продукты
#
# $ 1 - \frac{10}{70} \cdot \frac{9}{69} \cdot \frac{8}{68} \cdot \frac{7}{67} \cdot \frac{6}{66} - \frac{60}{70} \cdot \frac{59}{69} \cdot \frac{58}{68} \cdot \frac{57}{67} \cdot \frac{56}{66} \approx 0.55 $

# %%
onlyexpired_probability = (10/70)*(9/69)*(8/68)*(7/67)*(6/66)
onlynotexpired_probability = (60/70)*(59/69)*(58/68)*(57/67)*(56/66)

print(1-onlyexpired_probability-onlynotexpired_probability)
# Out:
# 0.5487269534679544

# %% [markdown]
# # Задание 2

# %% [markdown]
# # № 3. Условие
# На окружности радиуса r выбирается наудачу точка, и через нее проводится диаметр. На
# диаметре наудачу выбирается точка — середина хорды, перпендикулярной диаметру. Найти
# вероятность того, что длина полученной хорды превзойдет x.

# %% [markdown]
# # Решение
# $ P(A) = \frac{2\sqrt{r^2-(\frac{x}{2})^2}}{2r} = \sqrt{1 - (\frac{x}{2r})^2} $
#
# ![](circle.png)

# %% [markdown]
# # № 5. Условие
# На окружности радиуса r случайно выбираются две точки, которые служат концами хорды.
# С какой вероятностью длина хорды больше x?

# %% [markdown]
# # Решение
# $ P(A) = 1 - \frac{2arcsin(\frac{x}{2r})\cdot r}{2\pi \cdot r} = 1 - \frac{arcsin(\frac{x}{2r})}{\pi}$
#
# ![](circles2.png)

# %% [markdown]
# # Задание 3

# %% [markdown]
# ## № 3. Условие
# Введем события $ A_i = \{ X = i \} $, $ B_i = \{ Y = i \} $ i ⩾ 0. Известно, что для любых i ⩾ 0 и j ⩾ 0 события $ A_i $ и $ B_i $ – независимы,
#
# при этом $ P(X = i) = P(Y = i) = (1 - p)^i p $ , где, $ i ⩾ 0 $
#
# где $p ∈ (0, 1)$. Найти $P(X = i|X + Y = j)$.

# %% [markdown]
# ## Решение
# $ q = (1 - p) $
#
# $ P(X=i) = P(Y=i)= q^ip $
#
# $ P(X=i|X+Y=j) = \frac{P((X=i) \land (X+Y=j))}{P(X+Y=j)} = \frac{q^ip \cdot q^{(j-i)}p}{p \cdot q^jp + pq \cdot q^{j-1}p + pq^2 \cdot q^{j-2}p + ... + q^jp \cdot p} = \frac{q^jp^2}{(j+1)q^jp^2} = \frac{1}{j+1}$

# %% [markdown]
# # Задание 4

# %% [markdown]
# ## Условие
# Рассмотрите схемы Бернулли при $ n ∈ {100, 1000, 10000} $ и
# $ p ∈ {0.001, 0.01, 0.1, 0.25, 0.5} $ и рассчитайте точные вероятности (где это возможно)
# $ P(S_n ∈ [n/2 -\sqrt{npq}, n/2 + \sqrt{npq}]), P(S_n ⩽ 5) $ и максимальную вероятность вида $ P(S_n = k) $, $ S_n $
# – количество успехов в n испытаниях, и приближенные с помощью одной из предельных теорем.
# Сравните точные и приближенные вероятности. Объясните результаты.

# %% [markdown]
# ## Решение
# ### Почему в задаче спрашиваются именно такие интервалы и значения?
# * $ P(Sn≤5) $: Это стандартная задача на биномиальное распределение, где нас интересует вероятность того, что количество успехов не превысит определенного значения.
# * $  P(S_n \in [n/2 -\sqrt{npq}, n/2 + \sqrt{npq}]) $: Этот интервал выбран, так как вокруг среднего значения np биномиального распределения стандартное отклонение равно √npq.
# Таким образом, этот интервал включает в себя большую часть вероятностной массы распределения для больших n, и мы можем ожидать, что вероятность попадания в этот интервал будет высока.
# * Максимальная вероятность вида $  P(S_n = k)  $ означает, что из всех возможных значений k (от 0 до n) нужно найти то, которое максимизирует вероятность  $  P(S_n = k) $.

# %% [markdown]
# В этом варианте решения точные вероятности рассчитываются с использованием биномиального распределения, а приближенные - с использованием нормального распределения и распределения Пуассона. Оно наиболее точно когда n велико, а p мало, эта гипотеза подтвердится результатами (разница между точной и приближенной вероятностями в худшем случае, т.е. при $n=100$ и $p=0.5$ и $S_n <=5$ составляет более 0.7). Этот метод приближения в целом не отличается особой точностью, ибо даже в наилучшей комбинации $n$ и $p$ присутствует различие в сотых долях, поэтому далее будут исследованы более эффективные методы апроксимации. С помощью binom.cdf() (выбран метод cdf - cumulative distribution function, так как нам необходимо узнать вероятность того, что случайная величина примет значение, меньшее или равное указанному.)

# %%
from scipy.stats import binom, poisson
import numpy as np

n_values = [100, 1000, 10000]
p_values = [0.001, 0.01, 0.1, 0.25, 0.5]

results = []

for n in n_values:
    for p in p_values:
        q = 1 - p
        interval = [n / 2 - np.sqrt(n * p * q), n / 2 + np.sqrt(n * p * q)]
        exact_interval_prob = binom.cdf(interval[1], n, p) - binom.cdf(interval[0], n, p)
        exact_leq_5_prob = binom.cdf(5, n, p)
        max_prob = max(binom.pmf(k, n, p) for k in range(n+1))
        
        poisson_mean = n * p
        approx_interval_prob = poisson.cdf(interval[1], poisson_mean) - poisson.cdf(interval[0], poisson_mean)
        approx_leq_5_prob = poisson.cdf(5, poisson_mean)
        max_approx_prob = max(poisson.pmf(k, poisson_mean) for k in range(n+1))
        
        results.append({
            "n": n,
            "p": p,
            "exact_interval": exact_interval_prob,
            "exact_leq_5": exact_leq_5_prob,
            "max_exact_prob": max_prob,
            "approx_interval": approx_interval_prob,
            "approx_leq_5": approx_leq_5_prob,
            "max_approx_prob": max_approx_prob
        })

for result in results:
    print(f"n = {result['n']}, p = {result['p']}")
    print(f"Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): {result['exact_interval']}")
    print(f"Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) (Poisson): {result['approx_interval']}")
    print(f"Точная P(Sn ⩽ 5): {result['exact_leq_5']}")
    print(f"Приближенная P(Sn ⩽ 5) (Poisson): {result['approx_leq_5']}")
    print(f"Max точная P(Sn = k): {result['max_exact_prob']}")
    print(f"Max приближенная P(Sn = k) (Poisson): {result['max_approx_prob']}")
    print('_' * 50)
# Out:
# n = 100, p = 0.001
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 0.0
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) (Poisson): 0.0
# Точная P(Sn ⩽ 5): 0.9999999989001895
# Приближенная P(Sn ⩽ 5) (Poisson): 0.9999999987251013
# Max точная P(Sn = k): 0.9047921471137091
# Max приближенная P(Sn = k) (Poisson): 0.9048374180359595
# __________________________________________________
# n = 100, p = 0.01
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 0.0
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) (Poisson): 0.0
# Точная P(Sn ⩽ 5): 0.999465465536007
# Приближенная P(Sn ⩽ 5) (Poisson): 0.9994058151824183
# Max точная P(Sn = k): 0.36972963764972666
# Max приближенная P(Sn = k) (Poisson): 0.36787944117144233
# __________________________________________________
# n = 100, p = 0.1
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 0.0
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) (Poisson): 0.0
# Точная P(Sn ⩽ 5): 0.05757688648703396
# Приближенная P(Sn ⩽ 5) (Poisson): 0.06708596287903189
# Max точная P(Sn = k): 0.13186534682448794
# Max приближенная P(Sn = k) (Poisson): 0.12511003572113372
# __________________________________________________
# n = 100, p = 0.25
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 4.250444025410971e-06
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) (Poisson): 0.00010620812217232434
# Точная P(Sn ⩽ 5): 1.170014915408914e-07
# Приближенная P(Sn ⩽ 5) (Poisson): 1.3971121075428589e-06
# Max точная P(Sn = k): 0.0917996917668368
# Max приближенная P(Sn = k) (Poisson): 0.07952295146806541
# __________________________________________________
# n = 100, p = 0.5
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 0.6802726792997345
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) (Poisson): 0.5176039266343055
# Точная P(Sn ⩽ 5): 6.26162256269268e-23
# Приближенная P(Sn ⩽ 5) (Poisson): 5.567756260698086e-16
# Max точная P(Sn = k): 0.07958923738717875
# Max приближенная P(Sn = k) (Poisson): 0.05632500632519166
# __________________________________________________
# n = 1000, p = 0.001
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 0.0
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) (Poisson): 0.0
# Точная P(Sn ⩽ 5): 0.999411929898237
# Приближенная P(Sn ⩽ 5) (Poisson): 0.9994058151824183
# Max точная P(Sn = k): 0.36806348825922347
# Max приближенная P(Sn = k) (Poisson): 0.36787944117144233
# __________________________________________________
# n = 1000, p = 0.01
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 0.0
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) (Poisson): 0.0
# Точная P(Sn ⩽ 5): 0.0661395116072514
# Приближенная P(Sn ⩽ 5) (Poisson): 0.06708596287903189
# Max точная P(Sn = k): 0.1257402111262075
# Max приближенная P(Sn = k) (Poisson): 0.12511003572113372
# __________________________________________________
# n = 1000, p = 0.1
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 0.0
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) (Poisson): 0.0
# Точная P(Sn ⩽ 5): 2.5565456930600536e-38
# Приближенная P(Sn ⩽ 5) (Poisson): 3.261456366720447e-36
# Max точная P(Sn = k): 0.04201679086108606
# Max приближенная P(Sn = k) (Poisson): 0.03986099680914883
# __________________________________________________
# n = 1000, p = 0.25
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 0.0
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) (Poisson): 0.0
# Точная P(Sn ⩽ 5): 3.9691404522735886e-115
# Приближенная P(Sn ⩽ 5) (Poisson): 2.2163399192196057e-99
# Max точная P(Sn = k): 0.02912410588370507
# Max приближенная P(Sn = k) (Poisson): 0.025222916184525778
# __________________________________________________
# n = 1000, p = 0.5
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 0.673063317568404
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) (Poisson): 0.5118056361267036
# Точная P(Sn ⩽ 5): 7.738505306294352e-289
# Приближенная P(Sn ⩽ 5) (Poisson): 1.8740613464646944e-206
# Max точная P(Sn = k): 0.025225018178360824
# Max приближенная P(Sn = k) (Poisson): 0.017838267869512373
# __________________________________________________
# n = 10000, p = 0.001
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 0.0
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) (Poisson): 0.0
# Точная P(Sn ⩽ 5): 0.06699137339752664
# Приближенная P(Sn ⩽ 5) (Poisson): 0.06708596287903189
# Max точная P(Sn = k): 0.12517263665023912
# Max приближенная P(Sn = k) (Poisson): 0.12511003572113372
# __________________________________________________
# n = 10000, p = 0.01
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 0.0
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) (Poisson): 0.0
# Точная P(Sn ⩽ 5): 2.070048551692478e-36
# Приближенная P(Sn ⩽ 5) (Poisson): 3.261456366720447e-36
# Max точная P(Sn = k): 0.04006180577491359
# Max приближенная P(Sn = k) (Poisson): 0.03986099680914883
# __________________________________________________
# n = 10000, p = 0.1
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 0.0
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) (Poisson): 0.0
# Точная P(Sn ⩽ 5): 0.0
# Приближенная P(Sn ⩽ 5) (Poisson): 0.0
# Max точная P(Sn = k): 0.013296955574586395
# Max приближенная P(Sn = k) (Poisson): 0.012614611348719664
# __________________________________________________
# n = 10000, p = 0.25
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 0.0
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) (Poisson): 0.0
# Точная P(Sn ⩽ 5): 0.0
# Приближенная P(Sn ⩽ 5) (Poisson): 0.0
# Max точная P(Sn = k): 0.0092128446271744
# Max приближенная P(Sn = k) (Poisson): 0.007978579650977403
# __________________________________________________
# n = 10000, p = 0.5
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 0.6826652953470029
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) (Poisson): 0.5204708904652294
# Точная P(Sn ⩽ 5): 0.0
# Приближенная P(Sn ⩽ 5) (Poisson): 0.0
# Max точная P(Sn = k): 0.007978646139382158
# Max приближенная P(Sn = k) (Poisson): 0.005641801804685046
# __________________________________________________

# %% [markdown]
# В этом варианте решения рассмотрим вычисление приближенных вероятностей с использованием локальной теоремы Муавра-Лапласа ($ P(X = k) \approx \frac{1}{\sqrt{2\pi npq}} \cdot e^{-\frac{(k - np)^2}{2npq}}
# $). Этот метод аппроксимации является точным в случае, когда $n$ велико, а значения $p$ находятся вблизи $0.5$. Так, при $n = 10000$, а $p=0.5$ Max точная $P(S_n = k): 0.007978646139382158$, а Max приближенная $P(S_n = k) ≈ 0.007978845608028654$, что очень точно.
#
# Хотя она используется для приближенного вычисления вероятности конкретного числа успехов в схеме Бернулли, однако, её также можно использовать для вычисления вероятности того, что число успехов попадет в определенный интервал, суммируя вероятности для каждого значения в интервале.

# %%
import numpy as np
from math import sqrt, exp, pi

def moivre_laplace(n, p, k):
    q = 1 - p
    return 1 / sqrt(2 * pi * n * p * q) * exp(-((k - n * p) ** 2) / (2 * n * p * q))

n_values = [100, 1000, 10000]
p_values = [0.001, 0.01, 0.1, 0.25, 0.5]

results = []

for n in n_values:
    for p in p_values:
        q = 1 - p
        
        interval = [n / 2 - np.sqrt(n * p * q), n / 2 + np.sqrt(n * p * q)]
        exact_interval_prob = binom.cdf(interval[1], n, p) - binom.cdf(interval[0], n, p)
        exact_leq_5_prob = binom.cdf(5, n, p)
        max_ex_prob = max(binom.pmf(k, n, p) for k in range(n+1))

        # 1. P(Sn in [n/2 - sqrt(npq), n/2 + sqrt(npq)])
        lower_bound = int(n / 2 - sqrt(n * p * q))
        upper_bound = int(n / 2 + sqrt(n * p * q))
        prob_interval = sum(moivre_laplace(n, p, k) for k in range(lower_bound, upper_bound + 1))
        
        # 2. P(Sn <= 5)
        prob_leq_5 = sum(moivre_laplace(n, p, k) for k in range(6))
        
        # 3. Max P(Sn = k)
        max_prob = max(moivre_laplace(n, p, k) for k in range(n + 1))
        
        results.append({
            "n": n,
            "p": p,
            "exact_interval": exact_interval_prob,
            "exact_leq_5": exact_leq_5_prob,
            "max_exact_prob": max_ex_prob,
            "prob_interval": prob_interval,
            "prob_leq_5": prob_leq_5,
            "max_prob": max_prob
        })

for result in results:
    print(f"n = {result['n']}, p = {result['p']}")
    print(f"Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): {result['exact_interval']}")
    print(f"Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) ≈ {result['prob_interval']}")
    print(f"Точная P(Sn ⩽ 5): {result['exact_leq_5']}")
    print(f"Приближенная P(Sn ⩽ 5) ≈ {result['prob_leq_5']}")
    print(f"Max точная P(Sn = k): {result['max_exact_prob']}")
    print(f"Max приближенная P(Sn = k) ≈ {result['max_prob']}")
    print('_' * 50)
# Out:
# n = 100, p = 0.001
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 0.0
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) ≈ 0.0
# Точная P(Sn ⩽ 5): 0.9999999989001895
# Приближенная P(Sn ⩽ 5) ≈ 1.222480853594572
# Max точная P(Sn = k): 0.9047921471137091
# Max приближенная P(Sn = k) ≈ 1.2005793277351
# __________________________________________________
# n = 100, p = 0.01
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 0.0
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) ≈ 0.0
# Точная P(Sn ⩽ 5): 0.999465465536007
# Приближенная P(Sn ⩽ 5) ≈ 0.9424393138986122
# Max точная P(Sn = k): 0.36972963764972666
# Max приближенная P(Sn = k) ≈ 0.40095207790918386
# __________________________________________________
# n = 100, p = 0.1
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 0.0
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) ≈ 1.2590860811983577e-34
# Точная P(Sn ⩽ 5): 0.05757688648703396
# Приближенная P(Sn ⩽ 5) ≈ 0.06568670261055759
# Max точная P(Sn = k): 0.13186534682448794
# Max приближенная P(Sn = k) ≈ 0.13298076013381088
# __________________________________________________
# n = 100, p = 0.25
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 4.250444025410971e-06
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) ≈ 3.1913918618437575e-06
# Точная P(Sn ⩽ 5): 1.170014915408914e-07
# Приближенная P(Sn ⩽ 5) ≈ 3.1895997038182667e-06
# Max точная P(Sn = k): 0.0917996917668368
# Max приближенная P(Sn = k) ≈ 0.09213177319235613
# __________________________________________________
# n = 100, p = 0.5
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 0.6802726792997345
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) ≈ 0.7294683418607685
# Точная P(Sn ⩽ 5): 6.26162256269268e-23
# Приближенная P(Sn ⩽ 5) ≈ 2.4499543306723463e-19
# Max точная P(Sn = k): 0.07958923738717875
# Max приближенная P(Sn = k) ≈ 0.07978845608028654
# __________________________________________________
# n = 1000, p = 0.001
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 0.0
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) ≈ 0.0
# Точная P(Sn ⩽ 5): 0.999411929898237
# Приближенная P(Sn ⩽ 5) ≈ 0.9415401423624453
# Max точная P(Sn = k): 0.36806348825922347
# Max приближенная P(Sn = k) ≈ 0.3991419012697672
# __________________________________________________
# n = 1000, p = 0.01
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 0.0
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) ≈ 0.0
# Точная P(Sn ⩽ 5): 0.0661395116072514
# Приближенная P(Sn ⩽ 5) ≈ 0.07506233169135841
# Max точная P(Sn = k): 0.1257402111262075
# Max приближенная P(Sn = k) ≈ 0.12679217987703037
# __________________________________________________
# n = 1000, p = 0.1
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 0.0
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) ≈ 0.0
# Точная P(Sn ⩽ 5): 2.5565456930600536e-38
# Приближенная P(Sn ⩽ 5) ≈ 1.0747129413172746e-23
# Max точная P(Sn = k): 0.04201679086108606
# Max приближенная P(Sn = k) ≈ 0.042052208700336
# __________________________________________________
# n = 1000, p = 0.25
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 0.0
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) ≈ 1.2768064580904407e-66
# Точная P(Sn ⩽ 5): 3.9691404522735886e-115
# Приближенная P(Sn ⩽ 5) ≈ 1.214924583634303e-71
# Max точная P(Sn = k): 0.02912410588370507
# Max приближенная P(Sn = k) ≈ 0.029134624815788775
# __________________________________________________
# n = 1000, p = 0.5
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 0.673063317568404
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) ≈ 0.6882666144783667
# Точная P(Sn ⩽ 5): 7.738505306294352e-289
# Приближенная P(Sn ⩽ 5) ≈ 4.367881780479777e-215
# Max точная P(Sn = k): 0.025225018178360824
# Max приближенная P(Sn = k) ≈ 0.025231325220201602
# __________________________________________________
# n = 10000, p = 0.001
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 0.0
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) ≈ 0.0
# Точная P(Sn ⩽ 5): 0.06699137339752664
# Приближенная P(Sn ⩽ 5) ≈ 0.07597395371860657
# Max точная P(Sn = k): 0.12517263665023912
# Max приближенная P(Sn = k) ≈ 0.12621975176225178
# __________________________________________________
# n = 10000, p = 0.01
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 0.0
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) ≈ 0.0
# Точная P(Sn ⩽ 5): 2.070048551692478e-36
# Приближенная P(Sn ⩽ 5) ≈ 1.0310368470403859e-21
# Max точная P(Sn = k): 0.04006180577491359
# Max приближенная P(Sn = k) ≈ 0.04009520779091839
# __________________________________________________
# n = 10000, p = 0.1
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 0.0
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) ≈ 0.0
# Точная P(Sn ⩽ 5): 0.0
# Приближенная P(Sn ⩽ 5) ≈ 2.6889805115104844e-241
# Max точная P(Sn = k): 0.013296955574586395
# Max приближенная P(Sn = k) ≈ 0.013298076013381087
# __________________________________________________
# n = 10000, p = 0.25
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 0.0
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) ≈ 0.0
# Точная P(Sn ⩽ 5): 0.0
# Приближенная P(Sn ⩽ 5) ≈ 0.0
# Max точная P(Sn = k): 0.0092128446271744
# Max приближенная P(Sn = k) ≈ 0.009213177319235613
# __________________________________________________
# n = 10000, p = 0.5
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 0.6826652953470029
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) ≈ 0.6875127750307428
# Точная P(Sn ⩽ 5): 0.0
# Приближенная P(Sn ⩽ 5) ≈ 0.0
# Max точная P(Sn = k): 0.007978646139382158
# Max приближенная P(Sn = k) ≈ 0.007978845608028654
# __________________________________________________

# %% [markdown]
# В этом варианте решения рассмотрим вычисление приближенных вероятностей с использованием интегральной теоремы Муавра-Лапласа.

# %%
import numpy as np
from scipy.integrate import quad
from scipy.stats import binom

# Функция плотности вероятности стандартного нормального распределения
def f(t):
    return (1/np.sqrt(2*np.pi)) * np.exp(-t**2 / 2)

# Функция для вычисления функции распределения стандартного нормального распределения
def F(x):
    result, _ = quad(f, -np.inf, x)
    return result

n_values = [100, 1000, 10000]
p_values = [0.001, 0.01, 0.1, 0.25, 0.5]

results = []

for n in n_values:
    for p in p_values:
        q = 1 - p
        
        interval = [n / 2 - np.sqrt(n * p * q), n / 2 + np.sqrt(n * p * q)]
        exact_interval_prob = binom.cdf(interval[1], n, p) - binom.cdf(interval[0], n, p)
        exact_leq_5_prob = binom.cdf(5, n, p)
        max_prob = max(binom.pmf(k, n, p) for k in range(n+1))
        
        # 1. P(Sn in [n/2 - sqrt(npq), n/2 + sqrt(npq)])
        lower_bound = (n / 2 - np.sqrt(n * p * q) - n * p) / np.sqrt(n * p * q)
        upper_bound = (n / 2 + np.sqrt(n * p * q) - n * p) / np.sqrt(n * p * q)
        prob_interval = F(upper_bound) - F(lower_bound)
        
        # 2. P(Sn <= 5)
        prob_leq_5 = F((5 - n * p) / np.sqrt(n * p * q))
        
        # 3. Max P(Sn = k)
        max_k = round(n * p)
        prob_max_k = f((max_k - n * p) / np.sqrt(n * p * q)) / np.sqrt(n * p * q)
        
        results.append({
            "n": n,
            "p": p,
            "exact_interval": exact_interval_prob,
            "exact_leq_5": exact_leq_5_prob,
            "max_exact_prob": max_prob,
            "prob_interval": prob_interval,
            "prob_leq_5": prob_leq_5,
            "max_prob": prob_max_k
        })

for result in results:
    print(f"n = {result['n']}, p = {result['p']}")
    print(f"Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): {result['exact_interval']}")
    print(f"Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) ≈ {result['prob_interval']}")
    print(f"Точная P(Sn ⩽ 5): {result['exact_leq_5']}")
    print(f"Приближенная P(Sn ⩽ 5) ≈ {result['prob_leq_5']}")
    print(f"Max точная P(Sn = k): {result['max_exact_prob']}")
    print(f"Max приближенная P(Sn = k) ≈ {result['max_prob']}")
    print('_' * 50)
# Out:
# n = 100, p = 0.001
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 0.0
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) ≈ 0.0
# Точная P(Sn ⩽ 5): 0.9999999989001895
# Приближенная P(Sn ⩽ 5) ≈ 1.0
# Max точная P(Sn = k): 0.9047921471137091
# Max приближенная P(Sn = k) ≈ 1.2005793277351
# __________________________________________________
# n = 100, p = 0.01
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 0.0
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) ≈ -1.3878555876353912e-83
# Точная P(Sn ⩽ 5): 0.999465465536007
# Приближенная P(Sn ⩽ 5) ≈ 0.999970919606792
# Max точная P(Sn = k): 0.36972963764972666
# Max приближенная P(Sn = k) ≈ 0.4009520779091839
# __________________________________________________
# n = 100, p = 0.1
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 0.0
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) ≈ 1.1102230246251565e-16
# Точная P(Sn ⩽ 5): 0.05757688648703396
# Приближенная P(Sn ⩽ 5) ≈ 0.0477903522728147
# Max точная P(Sn = k): 0.13186534682448794
# Max приближенная P(Sn = k) ≈ 0.1329807601338109
# __________________________________________________
# n = 100, p = 0.25
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 4.250444025410971e-06
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) ≈ 9.052393574737749e-07
# Точная P(Sn ⩽ 5): 1.170014915408914e-07
# Приближенная P(Sn ⩽ 5) ≈ 1.9298081227866193e-06
# Max точная P(Sn = k): 0.0917996917668368
# Max приближенная P(Sn = k) ≈ 0.09213177319235613
# __________________________________________________
# n = 100, p = 0.5
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 0.6802726792997345
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) ≈ 0.6826894921370864
# Точная P(Sn ⩽ 5): 6.26162256269268e-23
# Приближенная P(Sn ⩽ 5) ≈ 1.1285884078346664e-19
# Max точная P(Sn = k): 0.07958923738717875
# Max приближенная P(Sn = k) ≈ 0.07978845608028654
# __________________________________________________
# n = 1000, p = 0.001
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 0.0
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) ≈ 0.0
# Точная P(Sn ⩽ 5): 0.999411929898237
# Приближенная P(Sn ⩽ 5) ≈ 0.9999685955499595
# Max точная P(Sn = k): 0.36806348825922347
# Max приближенная P(Sn = k) ≈ 0.3991419012697672
# __________________________________________________
# n = 1000, p = 0.01
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 0.0
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) ≈ 0.0
# Точная P(Sn ⩽ 5): 0.0661395116072514
# Приближенная P(Sn ⩽ 5) ≈ 0.056018421842781864
# Max точная P(Sn = k): 0.1257402111262075
# Max приближенная P(Sn = k) ≈ 0.12679217987703037
# __________________________________________________
# n = 1000, p = 0.1
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 0.0
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) ≈ -4.84469816418476e-34
# Точная P(Sn ⩽ 5): 2.5565456930600536e-38
# Приближенная P(Sn ⩽ 5) ≈ 6.62272979471773e-24
# Max точная P(Sn = k): 0.04201679086108606
# Max приближенная P(Sn = k) ≈ 0.042052208700336005
# __________________________________________________
# n = 1000, p = 0.25
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 0.0
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) ≈ 0.0
# Точная P(Sn ⩽ 5): 3.9691404522735886e-115
# Приближенная P(Sn ⩽ 5) ≈ 6.773737722659637e-72
# Max точная P(Sn = k): 0.02912410588370507
# Max приближенная P(Sn = k) ≈ 0.029134624815788775
# __________________________________________________
# n = 1000, p = 0.5
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 0.673063317568404
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) ≈ 0.682689492137087
# Точная P(Sn ⩽ 5): 7.738505306294352e-289
# Приближенная P(Sn ⩽ 5) ≈ 1.9002993793072287e-215
# Max точная P(Sn = k): 0.025225018178360824
# Max приближенная P(Sn = k) ≈ 0.025231325220201602
# __________________________________________________
# n = 10000, p = 0.001
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 0.0
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) ≈ 0.0
# Точная P(Sn ⩽ 5): 0.06699137339752664
# Приближенная P(Sn ⩽ 5) ≈ 0.056832776525984056
# Max точная P(Sn = k): 0.12517263665023912
# Max приближенная P(Sn = k) ≈ 0.12621975176225178
# __________________________________________________
# n = 10000, p = 0.01
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 0.0
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) ≈ 0.0
# Точная P(Sn ⩽ 5): 2.070048551692478e-36
# Приближенная P(Sn ⩽ 5) ≈ 6.620193813979559e-22
# Max точная P(Sn = k): 0.04006180577491359
# Max приближенная P(Sn = k) ≈ 0.040095207790918394
# __________________________________________________
# n = 10000, p = 0.1
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 0.0
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) ≈ 0.0
# Точная P(Sn ⩽ 5): 0.0
# Приближенная P(Sn ⩽ 5) ≈ 1.628611191505917e-241
# Max точная P(Sn = k): 0.013296955574586395
# Max приближенная P(Sn = k) ≈ 0.01329807601338109
# __________________________________________________
# n = 10000, p = 0.25
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 0.0
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) ≈ 2.1317123157251642e-76
# Точная P(Sn ⩽ 5): 0.0
# Приближенная P(Sn ⩽ 5) ≈ 0.0
# Max точная P(Sn = k): 0.0092128446271744
# Max приближенная P(Sn = k) ≈ 0.009213177319235613
# __________________________________________________
# n = 10000, p = 0.5
# Точная P(Sn ∈ [n/2 −√npq, n/2 + √npq]): 0.6826652953470029
# Приближенная P(Sn ∈ [n/2 −√npq, n/2 + √npq]) ≈ 0.6826894921370864
# Точная P(Sn ⩽ 5): 0.0
# Приближенная P(Sn ⩽ 5) ≈ 0.0
# Max точная P(Sn = k): 0.007978646139382158
# Max приближенная P(Sn = k) ≈ 0.007978845608028654
# __________________________________________________

# %% [markdown]
# Интегральная теорема Муавра-Лапласа оказалась самой точной из остальных аппроксимаций в целом. Наибольшей точности достигает при параметрах n = 10000, p = 0.5, а именно 6 знаков после запятой, так как для максимизации её точности нужно большое число испытаний и вероятности  успеха p и неудачи q не слишком близки к 0 и 1. Наименьшая точность при n = 100, p = 0.001, так как вероятность и количество испытаний слишком малы (особенно заметны различия в максимальных вероятностях)
# * При n = 100, p = 0.001 точная и приближенная вероятности попадания в интервал  $ P(S_n \in [n/2 -\sqrt{npq}, n/2 + \sqrt{npq}]) $ равны 0, так как вероятность p настолько мала, что значительное количество успехов маловероятно.
#
# * При n = 100, p = 0.1 вышла ситуация:
# Точная $ P(S_n \in [n/2 -\sqrt{npq}, n/2 + \sqrt{npq}]) $: 0.0 Приближенная $ P(S_n \in [n/2 -\sqrt{npq}, n/2 + \sqrt{npq}]) $ ≈ 1.1102230246251565e-16. Дело в том, что среднее значение $ \mu $ биномиального распределения np равно 10, а стандартное отклонение $\sigma$ равно $\sqrt{npq} = \sqrt{9} = 3$. Интервал $[n/2 -\sqrt{npq}, n/2 + \sqrt{npq}]$ в этом случае превращается в $[50-3, 50+3]$ = $[47, 53]$. Этот интервал далек от среднего значения распределения (которое равно 10), и поэтому вероятность того, что случайная величина попадет в этот интервал, равна 0 по биномиальному распределению.
# Однако при использовании интегральной теоремы Муавра-Лапласа возможно получить ненулевое значение, хотя и очень маленькое. Это связано с тем, что нормальное распределение простирается на бесконечность в обе стороны, и даже далеко от среднего значения есть ненулевая вероятность.

# %% [markdown]
# ## Графическое представление распределений

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

n_values = [100, 1000, 10000]
p_values = [0.001, 0.01, 0.1, 0.25, 0.5]

fig, axs = plt.subplots(len(n_values), 2, figsize=(10, 5 * len(n_values)))

for i, n in enumerate(n_values):
    for p in p_values:
        x = np.arange(0, n+1)
        pmf = binom.pmf(x, n, p)
        cdf = binom.cdf(x, n, p)
        
        axs[i, 0].plot(x, pmf, label=f'p = {p}')
        axs[i, 1].plot(x, cdf, label=f'p = {p}')
    
    axs[i, 0].set_title(f'Вероятностная функция масс (n = {n})')
    axs[i, 0].set_xlabel('k')
    axs[i, 0].set_ylabel('P(Sn = k)')
    axs[i, 0].legend()
    
    axs[i, 1].set_title(f'Кумулятивная функция распределения (n = {n})')
    axs[i, 1].set_xlabel('k')
    axs[i, 1].set_ylabel('P(Sn <= k)')
    axs[i, 1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# На графиках слева отображается функция вероятности, которая показывает вероятность того, что случайная величина примет конкретное значение. На графиках справа показана функция распределения, которая демонстрирует вероятность того, что случайная величина примет значение, меньшее или равное данному. В каждом случае построены графики для разных значений $ p $ при фиксированном $ n $.
#
# Здесь легко можно увидеть значения максимальных вероятностей, на cdf заметно, что с увеличением $n$ график функции вероятности становится всё менее плавным в экстремумах, а также то, что при $p = 0.5$ $n $ тоже равен половине из всех испытаний, при $p = 0.25$ - четверти и так далее. Это связано с увеличением точности и демонстрирует действие закона больших чисел (при большом числе испытаний доля успехов приблизительно равняется вероятности успеха).
# Пик графика pmf при $p = 0.5$ находится посеридине, при $p < 0.5$ сместится влево, при $p > 0.5$ - вправо. Максимальное значение уменьшается по мере увеличения $n$. Для меньших значений $n$ график может иметь более выраженные пики. Причиной служит увеличение исходов (иначе - уменьшению максимальной вероятности отдельного исхода) и сглаживание распределения, т.е. помере увеличения n биномиальное распределение приближается к нормальному распределению, и его график становится более сглаженным.
